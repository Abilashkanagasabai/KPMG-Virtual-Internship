# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
trans = pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name='Transactions')
new_cust = pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name='NewCustomerList')
cus_demo = pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name='CustomerDemographic')
address = pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name='CustomerAddress')

# %% [markdown]
# # Working with transactions

# %%
trans.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                     transaction_id
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    Unnamed: 1   Unnamed: 2           Unnamed: 3    Unnamed: 4    Unnamed: 5  \
# 0  product_id  customer_id     transaction_date  online_order  order_status
# 1           2         2950  2017-02-25 00:00:00         False      Approved
# 2           3         3120  2017-05-21 00:00:00          True      Approved
# 3          37          402  2017-10-16 00:00:00         False      Approved
# 4          88         3135  2017-08-31 00:00:00         False      Approved
#
# ...

# %%
trans.iloc[0].values
# Out:
# array(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'], dtype=object)

# %%
#Setting columns to dataframe
trans.columns=['transaction_id', 'product_id', 'customer_id', 'transaction_date',
       'online_order', 'order_status', 'brand', 'product_line',
       'product_class', 'product_size', 'list_price', 'standard_cost',
       'product_first_sold_date']

# %%
trans.drop(0,axis=0,inplace=True)

# %%
trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 1 to 20000
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  object
#  1   product_id               20000 non-null  object
#  2   customer_id              20000 non-null  object
#  3   transaction_date         20000 non-null  object
#  4   online_order             19640 non-null  object
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  object
#  11  standard_cost            19803 non-null  object
#  12  product_first_sold_date  19803 non-null  object
# dtypes: object(13)
# memory usage: 2.1+ MB

# %%
trans[["transaction_id", "product_id","customer_id",'list_price', 'standard_cost']] = trans[["transaction_id", "product_id","customer_id",'list_price', 'standard_cost']].apply(pd.to_numeric,errors='coerce')

# %%
trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 1 to 20000
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  object
#  4   online_order             19640 non-null  object
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  object
# dtypes: float64(2), int64(3), object(8)
# ...

# %%
#convert date columns from integer to datetime
trans['product_first_sold_date'] = pd.to_datetime(trans['product_first_sold_date'],errors='coerce',unit='s')
trans['product_first_sold_date'].head()
# Out:
# 1   1970-01-01 11:27:25
# 2   1970-01-01 11:35:01
# 3   1970-01-01 10:06:01
# 4   1970-01-01 10:02:25
# 5   1970-01-01 11:43:46
# Name: product_first_sold_date, dtype: datetime64[ns]

# %%
trans.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 1 to 20000
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  object
#  4   online_order             19640 non-null  object
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  datetime64[ns]
# ...

# %%
trans.head()
# Out:
#    transaction_id  product_id  customer_id     transaction_date online_order  \
# 1               1           2         2950  2017-02-25 00:00:00        False
# 2               2           3         3120  2017-05-21 00:00:00         True
# 3               3          37          402  2017-10-16 00:00:00        False
# 4               4          88         3135  2017-08-31 00:00:00        False
# 5               5          78          787  2017-10-01 00:00:00         True
#
#   order_status           brand product_line product_class product_size  \
# 1     Approved           Solex     Standard        medium       medium
# 2     Approved   Trek Bicycles     Standard        medium        large
# 3     Approved      OHM Cycles     Standard           low       medium
# 4     Approved  Norco Bicycles     Standard        medium       medium
# 5     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost product_first_sold_date
# ...

# %%
trans.describe()
# Out:
#        transaction_id   product_id   customer_id    list_price  standard_cost
# count    20000.000000  20000.00000  20000.000000  20000.000000   19803.000000
# mean     10000.500000     45.36465   1738.246050   1107.829449     556.046951
# std       5773.647028     30.75359   1011.951046    582.825242     405.955660
# min          1.000000      0.00000      1.000000     12.010000       7.210000
# 25%       5000.750000     18.00000    857.750000    575.270000     215.140000
# 50%      10000.500000     44.00000   1736.000000   1163.890000     507.580000
# 75%      15000.250000     72.00000   2613.000000   1635.300000     795.100000
# max      20000.000000    100.00000   5034.000000   2091.470000    1759.850000

# %%
print(trans.shape)
# Out:
# (20000, 13)

# %%
trans.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
dups = trans.duplicated()
trans[dups].sum()
# Out:
# transaction_id             0.0
# product_id                 0.0
# customer_id                0.0
# transaction_date           0.0
# online_order               0.0
# order_status               0.0
# brand                      0.0
# product_line               0.0
# product_class              0.0
# product_size               0.0
# list_price                 0.0
# standard_cost              0.0
# product_first_sold_date    0.0
# dtype: float64

# %%
trans['order_status'].value_counts()
# Out:
# Approved     19821
# Cancelled      179
# Name: order_status, dtype: int64

# %%
trans['online_order'].value_counts()
# Out:
# True     9829
# False    9811
# Name: online_order, dtype: int64

# %%
trans['brand'].value_counts()
# Out:
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64

# %%
trans['product_line'].value_counts()
# Out:
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: product_line, dtype: int64

# %% [markdown]
# # Working with New Customer List Dataset¶

# %%
new_cust.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                         first_name
# 1                                            Chickie
# 2                                              Morly
# 3                                            Ardelis
# 4                                             Lucine
#
#   Unnamed: 1 Unnamed: 2                           Unnamed: 3  \
# 0  last_name     gender  past_3_years_bike_related_purchases
# 1    Brister       Male                                   86
# 2     Genery       Male                                   69
# 3  Forrester     Female                                   10
# 4      Stutt     Female                                   64
#
#             Unnamed: 4                  Unnamed: 5             Unnamed: 6  \
# 0                  DOB                   job_title  job_industry_category
# ...

# %%
new_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 23 columns):
#  #   Column                                                                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                                                                         --------------  -----
#  0   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   1001 non-null   object
#  1   Unnamed: 1                                                                                                                                                                     972 non-null    object
# ...

# %%
to_drop = ['Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20']
new_cust.drop(to_drop, axis=1,inplace=True)

# %%
new_cust.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                         first_name
# 1                                            Chickie
# 2                                              Morly
# 3                                            Ardelis
# 4                                             Lucine
#
#   Unnamed: 1 Unnamed: 2                           Unnamed: 3  \
# 0  last_name     gender  past_3_years_bike_related_purchases
# 1    Brister       Male                                   86
# 2     Genery       Male                                   69
# 3  Forrester     Female                                   10
# 4      Stutt     Female                                   64
#
#             Unnamed: 4                  Unnamed: 5             Unnamed: 6  \
# 0                  DOB                   job_title  job_industry_category
# ...

# %%
new_cust.iloc[0].values
# Out:
# array(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Rank', 'Value'], dtype=object)

# %%
new_cust.columns=['first_name', 'last_name', 'gender',
       'past_3_years_bike_related_purchases', 'DOB', 'job_title',
       'job_industry_category', 'wealth_segment', 'deceased_indicator',
       'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
       'property_valuation', 'Rank', 'Value']

# %%
new_cust.drop(0,axis=0)
# Out:
#      first_name  last_name  gender past_3_years_bike_related_purchases  \
# 1       Chickie    Brister    Male                                  86
# 2         Morly     Genery    Male                                  69
# 3       Ardelis  Forrester  Female                                  10
# 4        Lucine      Stutt  Female                                  64
# 5       Melinda     Hadlee  Female                                  34
# ...         ...        ...     ...                                 ...
# 996   Ferdinand  Romanetti    Male                                  60
# 997        Burk    Wortley    Male                                  22
# 998    Melloney      Temby  Female                                  17
# 999      Dickie    Cubbini    Male                                  30
# 1000      Sylas    Duffill    Male                                  56
#
#                       DOB                     job_title job_industry_category  \
# ...

# %%
new_cust.head()
# Out:
#    first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0  first_name  last_name  gender  past_3_years_bike_related_purchases
# 1     Chickie    Brister    Male                                   86
# 2       Morly     Genery    Male                                   69
# 3     Ardelis  Forrester  Female                                   10
# 4      Lucine      Stutt  Female                                   64
#
#                    DOB                   job_title  job_industry_category  \
# 0                  DOB                   job_title  job_industry_category
# 1           1957-07-12             General Manager          Manufacturing
# 2           1970-03-22         Structural Engineer               Property
# 3  1974-08-28 00:00:00      Senior Cost Accountant     Financial Services
# 4           1979-01-28  Account Representative III          Manufacturing
#
#       wealth_segment  deceased_indicator  owns_car  tenure  \
# ...

# %%
new_cust.drop(0,axis=0)
# Out:
#      first_name  last_name  gender past_3_years_bike_related_purchases  \
# 1       Chickie    Brister    Male                                  86
# 2         Morly     Genery    Male                                  69
# 3       Ardelis  Forrester  Female                                  10
# 4        Lucine      Stutt  Female                                  64
# 5       Melinda     Hadlee  Female                                  34
# ...         ...        ...     ...                                 ...
# 996   Ferdinand  Romanetti    Male                                  60
# 997        Burk    Wortley    Male                                  22
# 998    Melloney      Temby  Female                                  17
# 999      Dickie    Cubbini    Male                                  30
# 1000      Sylas    Duffill    Male                                  56
#
#                       DOB                     job_title job_industry_category  \
# ...

# %%
new_cust.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Rank                                     0
# Value                                    0
# dtype: int64

# %%
new_cust.duplicated().sum()
# Out:
# 0

# %%
new_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1001 non-null   object
#  1   last_name                            972 non-null    object
#  2   gender                               1001 non-null   object
#  3   past_3_years_bike_related_purchases  1001 non-null   object
#  4   DOB                                  984 non-null    object
#  5   job_title                            895 non-null    object
#  6   job_industry_category                836 non-null    object
#  7   wealth_segment                       1001 non-null   object
#  8   deceased_indicator                   1001 non-null   object
#  9   owns_car                             1001 non-null   object
#  10  tenure                               1001 non-null   object
# ...

# %%
new_cust[["past_3_years_bike_related_purchases","tenure",'postcode', 'property_valuation','Rank','Value']] = new_cust[["past_3_years_bike_related_purchases","tenure",'postcode', 'property_valuation','Rank','Value']].apply(pd.to_numeric,errors='coerce')

# %%
new_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1001 non-null   object
#  1   last_name                            972 non-null    object
#  2   gender                               1001 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   float64
#  4   DOB                                  984 non-null    object
#  5   job_title                            895 non-null    object
#  6   job_industry_category                836 non-null    object
#  7   wealth_segment                       1001 non-null   object
#  8   deceased_indicator                   1001 non-null   object
#  9   owns_car                             1001 non-null   object
#  10  tenure                               1000 non-null   float64
# ...

# %%
new_cust['gender'].value_counts()
# Out:
# Female    513
# Male      470
# U          17
# gender      1
# Name: gender, dtype: int64

# %% [markdown]
# # Working with Customer Demographic Dataset¶
# #

# %%
cus_demo.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                        customer_id
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3                           Unnamed: 4  \
# 0  first_name  last_name     gender  past_3_years_bike_related_purchases
# 1     Laraine  Medendorp          F                                   93
# 2         Eli    Bockman       Male                                   81
# 3       Arlin     Dearle       Male                                   61
# 4      Talbot        NaN       Male                                   33
#
#             Unnamed: 5              Unnamed: 6             Unnamed: 7  \
# ...

# %%
cus_demo.iloc[0].values
# Out:
# array(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'], dtype=object)

# %%
cus_demo.columns=['customer_id', 'first_name', 'last_name', 'gender',
       'past_3_years_bike_related_purchases', 'DOB', 'job_title',
       'job_industry_category', 'wealth_segment', 'deceased_indicator',
       'default', 'owns_car', 'tenure']

# %%
cus_demo.drop(0,axis=0,inplace=True)

# %%
cus_demo.head()
# Out:
#   customer_id      first_name  last_name  gender  \
# 1           1         Laraine  Medendorp       F
# 2           2             Eli    Bockman    Male
# 3           3           Arlin     Dearle    Male
# 4           4          Talbot        NaN    Male
# 5           5  Sheila-kathryn     Calton  Female
#
#   past_3_years_bike_related_purchases                  DOB  \
# 1                                  93  1953-10-12 00:00:00
# 2                                  81  1980-12-16 00:00:00
# 3                                  61  1954-01-20 00:00:00
# 4                                  33  1961-10-03 00:00:00
# 5                                  56  1977-05-13 00:00:00
#
#                 job_title job_industry_category     wealth_segment  \
# 1     Executive Secretary                Health      Mass Customer
# 2  Administrative Officer    Financial Services      Mass Customer
# 3      Recruiting Manager              Property      Mass Customer
# ...

# %%
cus_demo["default"]
# Out:
# 1                                                      "'
# 2                            <script>alert('hi')</script>
# 3                                     2018-02-01 00:00:00
# 4       () { _; } >_[$($())] { touch /tmp/blns.shellsh...
# 5                                                     NIL
#                               ...
# 3996                                                 -100
# 3997                                             â¦testâ§
# 3998                                                  NaN
# 3999                               Â¡â¢Â£Â¢âÂ§Â¶â¢ÂªÂºââ
# 4000                                                  0/0
# Name: default, Length: 4000, dtype: object

# %%
cus_demo.drop("default",axis=1,inplace=True)

# %%
cus_demo.head()
# Out:
#   customer_id      first_name  last_name  gender  \
# 1           1         Laraine  Medendorp       F
# 2           2             Eli    Bockman    Male
# 3           3           Arlin     Dearle    Male
# 4           4          Talbot        NaN    Male
# 5           5  Sheila-kathryn     Calton  Female
#
#   past_3_years_bike_related_purchases                  DOB  \
# 1                                  93  1953-10-12 00:00:00
# 2                                  81  1980-12-16 00:00:00
# 3                                  61  1954-01-20 00:00:00
# 4                                  33  1961-10-03 00:00:00
# 5                                  56  1977-05-13 00:00:00
#
#                 job_title job_industry_category     wealth_segment  \
# 1     Executive Secretary                Health      Mass Customer
# 2  Administrative Officer    Financial Services      Mass Customer
# 3      Recruiting Manager              Property      Mass Customer
# ...

# %%
cus_demo[["customer_id",'past_3_years_bike_related_purchases', 'tenure']] = cus_demo[["customer_id",'past_3_years_bike_related_purchases', 'tenure']].apply(pd.to_numeric,errors='coerce')

# %%
cus_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 1 to 4000
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   object
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  owns_car                             4000 non-null   object
# ...

# %%
new_cust.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      1
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   1
# address                                  0
# postcode                                 1
# state                                    0
# country                                  0
# property_valuation                       1
# Rank                                     1
# Value                                    1
# dtype: int64

# %%
cus_demo['gender'].value_counts()
# Out:
# Female    2037
# Male      1872
# U           88
# Femal        1
# F            1
# M            1
# Name: gender, dtype: int64

# %% [markdown]
# # Working with Address Dataset¶

# %%
address.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                        customer_id
# 1                                                  1
# 2                                                  2
# 3                                                  4
# 4                                                  5
#
#             Unnamed: 1 Unnamed: 2       Unnamed: 3 Unnamed: 4  \
# 0              address   postcode            state    country
# 1   060 Morning Avenue       2016  New South Wales  Australia
# 2  6 Meadow Vale Court       2153  New South Wales  Australia
# 3   0 Holy Cross Court       4211              QLD  Australia
# 4  17979 Del Mar Point       2448  New South Wales  Australia
#
#            Unnamed: 5
# 0  property_valuation
# 1                  10
# 2                  10
# 3                   9
# 4                   4

# %%
address.iloc[0].values
# Out:
# array(['customer_id', 'address', 'postcode', 'state', 'country',
#        'property_valuation'], dtype=object)

# %%
address.columns=['customer_id', 'address', 'postcode', 'state', 'country','property_valuation']

# %%
address.drop(0,axis=0,inplace=True)

# %%
address.head()
# Out:
#   customer_id              address postcode            state    country  \
# 1           1   060 Morning Avenue     2016  New South Wales  Australia
# 2           2  6 Meadow Vale Court     2153  New South Wales  Australia
# 3           4   0 Holy Cross Court     4211              QLD  Australia
# 4           5  17979 Del Mar Point     2448  New South Wales  Australia
# 5           6     9 Oakridge Court     3216              VIC  Australia
#
#   property_valuation
# 1                 10
# 2                 10
# 3                  9
# 4                  4
# 5                  9

# %%
address.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3999 entries, 1 to 3999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   object
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   object
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   object
# dtypes: object(6)
# memory usage: 218.7+ KB

# %%
address[["customer_id",'postcode', 'property_valuation']] = address[["customer_id",'postcode', 'property_valuation']].apply(pd.to_numeric,errors='coerce')

# %%
address.isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
cus_demo.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 1            1         Laraine  Medendorp       F
# 2            2             Eli    Bockman    Male
# 3            3           Arlin     Dearle    Male
# 4            4          Talbot        NaN    Male
# 5            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases                  DOB  \
# 1                                   93  1953-10-12 00:00:00
# 2                                   81  1980-12-16 00:00:00
# 3                                   61  1954-01-20 00:00:00
# 4                                   33  1961-10-03 00:00:00
# 5                                   56  1977-05-13 00:00:00
#
#                 job_title job_industry_category     wealth_segment  \
# 1     Executive Secretary                Health      Mass Customer
# 2  Administrative Officer    Financial Services      Mass Customer
# 3      Recruiting Manager              Property      Mass Customer
# ...

# %%
cus_demo.shape
# Out:
# (4000, 12)

# %%
new_cust.head()
# Out:
#    first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0  first_name  last_name  gender                                  NaN
# 1     Chickie    Brister    Male                                 86.0
# 2       Morly     Genery    Male                                 69.0
# 3     Ardelis  Forrester  Female                                 10.0
# 4      Lucine      Stutt  Female                                 64.0
#
#                    DOB                   job_title  job_industry_category  \
# 0                  DOB                   job_title  job_industry_category
# 1           1957-07-12             General Manager          Manufacturing
# 2           1970-03-22         Structural Engineer               Property
# 3  1974-08-28 00:00:00      Senior Cost Accountant     Financial Services
# 4           1979-01-28  Account Representative III          Manufacturing
#
#       wealth_segment  deceased_indicator  owns_car  tenure  \
# ...

# %%
new_cust.shape
# Out:
# (1001, 18)
